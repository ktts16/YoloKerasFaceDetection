# %%
from panya_s.utils import align
import cv2
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
img = cv2.imread("/home/krittametht/dataset/UTKFace_inthewild/1_0_2_20161219162544751.jpg")[...,::-1]

# %%
aimg = align(img, 227)

# %%
plt.imshow(img)

# %%
plt.imshow(aimg)
